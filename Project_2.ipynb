# %% [markdown]
# <h1>Sumário<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import openaq
import warnings

warnings.simplefilter('ignore')

# %%
# Criar instância do API 
api = openaq.OpenAQ()

# %%
api.measurements(df=True,country='BR')
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-36-fbf0693e13a1> in <module>
# ----> 1 api.measurements(df=True,country='BR')
#
# ~\anaconda3\lib\site-packages\openaq\decorators.py in decorated_function(*args, **kwargs)
#      35
#      36             if df == True and _no_pandas == False:
# ---> 37                 status, resp = f(*args, **kwargs)
#      38
#      39                 if status == 200:
#
# ~\anaconda3\lib\site-packages\openaq\__init__.py in measurements(self, **kwargs)
#     416         }
#     417         """
# --> 418         return self._get('measurements', **kwargs)
#     419
#     420     def fetches(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\openaq\__init__.py in _get(self, url, **kwargs)
#      82
#      83     def _get(self, url, **kwargs):
# ---> 84         return self._send(url, 'GET', **kwargs)
#      85
# ...

# %%
# requisitar dataset,
df_airQ_BR = api.latest(df=True, limit=100000,index='utc', country='BR')

# Transformar o index em conluna (datas)
df_airQ_BR.reset_index(level=0, inplace=True)

df_airQ_BR.sample(10)
# Out:
#                     lastUpdated parameter  value                    unit  \
# 36941 2016-01-26 10:00:00+00:00       no2   30.0  b'\xc2\xb5g/m\xc2\xb3'
# 44879 2016-01-26 23:00:00+00:00       no2   39.0  b'\xc2\xb5g/m\xc2\xb3'
# 22881 2016-01-26 22:00:00+00:00      pm10   22.0  b'\xc2\xb5g/m\xc2\xb3'
# 1343  2016-01-25 10:00:00+00:00        co    1.0                     ppm
# 4436  2016-01-25 10:00:00+00:00        co    1.0                     ppm
# 10047 2015-10-09 23:00:00+00:00       so2    4.0  b'\xc2\xb5g/m\xc2\xb3'
# 55949 2016-01-24 00:00:00+00:00      pm25   15.0  b'\xc2\xb5g/m\xc2\xb3'
# 47095 2016-01-26 23:00:00+00:00       no2   39.0  b'\xc2\xb5g/m\xc2\xb3'
# 10004 2015-10-09 23:00:00+00:00       so2    4.0  b'\xc2\xb5g/m\xc2\xb3'
# 7262  2016-01-25 10:00:00+00:00        co    1.0                     ppm
#
#       sourceName country                           city  \
# 36941  Sao Paulo      BR                   Paulínia-Sul
# ...

# %%
df_airQ_BR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58693 entries, 0 to 58692
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   lastUpdated            58693 non-null  datetime64[ns, UTC]
#  1   parameter              58693 non-null  object
#  2   value                  58693 non-null  float64
#  3   unit                   58693 non-null  object
#  4   sourceName             58693 non-null  object
#  5   country                58693 non-null  object
#  6   city                   58693 non-null  object
#  7   location               58693 non-null  object
#  8   averagingPeriod.value  58693 non-null  int64
#  9   averagingPeriod.unit   58693 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(1), object(7)
# memory usage: 4.5+ MB

# %%
# Out:
#               value  averagingPeriod.value
# count  58693.000000                58693.0
# mean      20.254429                    1.0
# std       13.489964                    0.0
# min        0.000000                    1.0
# 25%        4.000000                    1.0
# 50%       22.000000                    1.0
# 75%       30.000000                    1.0
# max      142.000000                    1.0

# %%
# Out:
#                           parameter  value                    unit sourceName  \
# lastUpdated
# 2015-10-24 00:00:00+00:00        o3   28.0  b'\xc2\xb5g/m\xc2\xb3'  Sao Paulo
# 2016-01-26 23:00:00+00:00       no2   39.0  b'\xc2\xb5g/m\xc2\xb3'  Sao Paulo
# 2016-01-26 22:00:00+00:00      pm10   22.0  b'\xc2\xb5g/m\xc2\xb3'  Sao Paulo
# 2016-01-24 00:00:00+00:00      pm25   15.0  b'\xc2\xb5g/m\xc2\xb3'  Sao Paulo
# 2016-01-24 00:00:00+00:00      pm25   15.0  b'\xc2\xb5g/m\xc2\xb3'  Sao Paulo
#
#                           country                           city  \
# lastUpdated
# 2015-10-24 00:00:00+00:00      BR             Nossa Senhora do Ó
# 2016-01-26 23:00:00+00:00      BR             São Caetano do Sul
# 2016-01-26 22:00:00+00:00      BR  Marg.Tietê-Ponte dos Remédios
# 2016-01-24 00:00:00+00:00      BR          São José do Rio Preto
# 2016-01-24 00:00:00+00:00      BR          São José do Rio Preto
#
#                                                 location  \
# lastUpdated
# ...
